# %% [markdown]
# Scratch workbook for calculations to avoid cluttering the main analysis file.

# %%
# import packages, files and the data set needed

# Import packages and files

# math and data packages
import pandas as pd
import numpy as np
import math
from scipy import ndimage

# charting and graphics
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from matplotlib.gridspec import GridSpec
import matplotlib.image as mpimg

# os and file types
import os
import sys
import datetime as dt
import json
import csv

# images and display
import base64, io, IPython
from PIL import Image as PILImage
from IPython.display import Markdown as md
from IPython.display import display

# import survey data and initialize datetime
spd=pd.read_csv("resources/survey_data_lists_02_22.csv")
spd["date"] = pd.to_datetime(spd['date'], errors='coerce', format='%Y-%m-%d')
spd["month"] = spd["date"].dt.month

# create column of mutually exclusive plant characteristics from dataset
spdint1 = spd[spd["inv"]!="X"].copy()
spdint1["allstats"] = spdint1["inv"]
spdint2 = spd[spd["ns"]!="X"].copy()
spdint2["allstats"] = spdint2["ns"]
spdint3 = spd[spd["rch"]!="X"].copy()
spdint3["allstats"] = spdint3["rch"]
spdint4 = spd[spd["ni"]!="X"].copy()
spdint4["allstats"] = spdint4["ni"]
spdint5 = spd[spd["ongen"]!="X"].copy()
spdint5["allstats"] = spdint5["ongen"]
spd_allstats = pd.concat([spdint1, spdint2, spdint3, spdint4, spdint5])

# create yearly data for later charting use
spd1 = spd_allstats.loc[spd_allstats.year == 1].copy()
spd2 = spd_allstats.loc[(spd_allstats["year"] == 2)].copy()

#import 5X5 data
biel51 = pd.read_csv("resources/atlas5x5/Atlas5x5_580_220.csv", encoding = "utf-16")
biel52 = pd.read_csv("resources/atlas5x5/Atlas5x5_580_215.csv", encoding = "utf-16")
biel53 = pd.read_csv("resources/atlas5x5/Atlas5x5_580_220.csv", encoding = "utf-16")
biel54 = pd.read_csv("resources/atlas5x5/Atlas5x5_580_220.csv", encoding = "utf-16")

ger=pd.read_csv("resources/germ_data.csv")
ger["pdate"] = pd.to_datetime(ger['pdate'], errors='coerce', format='%d/%m/%y')

# %%
# comparison with 5x5 observations around biel

# set up the 4 5x5 km observation boxes from infoflora that meet in Biel/Bienne into one database indexed on species.

# convert the infoflora species name to species slugs to be compatible
def to_slug(x):
    try: 
        int_data = x.split()
        data = int_data[:2]
        data = "-".join(data)
        data = data.lower()
    except:
        data = "none"
    return data

for a in biel51.species:
    biel51["species"] = biel51["species"].map(lambda x: to_slug(x))
biel51["biel51"] = "biel51"
biel51.set_index("species", inplace=True, drop=True)

for a in biel52.species:
    biel52["species"] = biel52["species"].map(lambda x: to_slug(x))
biel52["biel51"] = "biel52"
biel52.set_index("species", inplace=True, drop=True)

for a in biel53.species:
    biel53["species"] = biel53["species"].map(lambda x: to_slug(x))
biel53["biel53"] = "biel53"
biel53.set_index("species", inplace=True, drop=True)

for a in biel54.species:
    biel54["species"] = biel54["species"].map(lambda x: to_slug(x))
biel54["biel54"] = "biel54"
biel54.set_index("species", inplace=True, drop=True)
a = biel51.index

# combine the observations into a dataframe indexed on species
biel_species = set([*biel51.index, *biel52.index, *biel53.index, *biel54.index])
bs = pd.DataFrame(index=biel_species)
bs["biel"] = "biel"


# remove the "ongen" observations from the survey dataset as they won't be in the infoflora observations

spd_ongenno = spd_allstats[spd_allstats["species"].str.contains("-")]

# make list in data of species identified in infoflora that were not identified in surveys

data = []

for a in spd_ongenno.species.unique():
    if a not in bs.index:
        data.append(a)
notin5x5 = pd.DataFrame({"col":data})

# %%
# calculate species refinement
biel = spd_ongenno.biel.value_counts()
cdf = spd_ongenno.cdf.value_counts()
noneint = spd_ongenno[spd_ongenno.biel=="X"]
none = noneint[noneint.cdf=="X"]
specieslist = none.species.unique()

# %%
# germination containers
cont = ger.loc[ger.container == "plastic-tray"].copy()
conc = ger.loc[ger.container == "concrete-container"].copy()

# %%
conc.columns
# Out:
# Index(['species', 'recs', 'recn', 'recp', 'collection', 'origin', 'geo',
#        'colm', 'coly', 'sloc', 'storage-comment', 'pdate', 'pmet', 'container',
#        'area', 'density', '2021-10-10', '2021-10-12', '2021-10-14',
#        '2021-10-16', '2021-10-18', '2021-10-20', '2021-10-22', '2021-10-24',
#        '2021-10-26', '2021-10-28', '2021-10-30', '2021-11-03', '2021-11-10',
#        '2021-11-18', '2021-11-23', '2021-11-28', 'genus', 'int'],
#       dtype='object')

# %%
conc.replace("full", 200)
# Out:
#                      species recs recn recp collection           origin  \
# 12            felseck-flower   dd   dd   dd   personal          felseck
# 13             felseck-grass   dd   dd   dd   personal          felseck
# 48  helianthemum-nummularium  yes  yes   no    port 34          port-34
# 49           silene-arvensis    x    x    x    port 34  rue-de-l'avenir
# 50     matricaria-chamomilla    x    x    x    port 34       cygnes-lot
# 51          malva-sylvestris    x  yes    x    port 34       cygnes-lot
# 52      hypericum-perforatum  yes  yes   no    port 34          port-34
# 53     campanula-perscifolia    x   no  yes    port 34          port-34
# 54         cichorium-intybus    x  yes  yes    port 34  ursula-albrecht
# 55           aster-linosyrus    x   no   no    port 34           ticino
# 56           lathyrus-vernus    x  yes   no    port 34          port-34
# 57       geranium-sylvaticum    x  yes  yes    port 34          port-34
# 58       verbena-officinalis    x    x    x    port 34         port-lot
# 59         dipsacus-fullonum    x    x    x    port 34         port-lot
# 60       trifolium-campestre  yes  yes    x    port 34          felseck
# 61              geum-urbanum  yes  yes    x    port 34          pfeidli
# 62        epilobium-dodonaie    x   no   no    port 34          port-34
# 63          isatis-tinctoria    x  yes    x    port 34             bern
# 64     matricaria-chamomilla    x    x    x    port 34          port-34
# 65     lavendula-officinalis    x    x    x    port 34          port-34
# 66          salvia-pratensis    x  yes    x    port 34          port-34
# 67        anthemis-tinctoria    x  yes    x    port 34          port-34
# 68                  viola-sp   dd   dd   dd   personal    pres-la-patte
# 69          verbascum-nigrum    x  yes  yes    port 34          port-34
# 70     levisticum-officinale    x  yes    x    port 34          port-34
# 71       polemonium-caerulum    x   no    x    port 34          port-34
# 72       plantago-lanceolata    x    x    x   personal       cygnes-lot
# 73      melilotus-officinale    x    x    x   personal       cygnes-lot
# 74               malva-alcea    x   no    x   personal     zentralplatz
# 75             daucus-carota    x    x    x   personal       cygnes-lot
# 76       scabiosa-columbaria    x    x   no    port 34          port-34
# 77     valeriana-officinalis  yes  yes    x    port 34          port-34
# 78             aster-amellus    x   no   no    port 34          port-34
# 79         teucrium-montanum    x    x    x   personal          felseck
# 80       teucrium-chamaedrys    x  yes   no   personal          felseck
# 81   campanula-rapunculoides   no   no    x    port 34          port-34
# 82           cirsium-arvense    x    x    x   personal       cygnes-lot
# 83           special-felseck   dd   dd   dd   personal          felseck
# 84            plantago-media    x    x    x   personal        alt-stadt
# 85      achillea-millefolium    x    x    x   personal          cdf-cff
# 86       filipendula-ulmaria    x    x    x   personal          cdf-cff
# 87     heracleum-sphondylium    x    x    x   personal          cdf-cff
# 88         prunella-vulgaris    x    x    x   personal        alt-stadt
# 89      achillea-millefolium    x    x    x   personal          cdf-cff
# 90                 malva-sp.   dd   dd   dd   personal          cdf-cff
#
#             geo colm  coly     sloc  ... 2021-10-26 2021-10-28 2021-10-30  \
# 12         biel    9  2021     home  ...         18         19         22
# 13         biel    9  2021     home  ...         31         32         37
# 48      port 34    x  2020  port 34  ...          0          2          2
# 49         biel    x  2020     home  ...        200        200        200
# 50         biel    x  2020     home  ...         19         19         20
# 51         biel    x  2020     home  ...        200        200        200
# 52      port 34    x  2020  port 34  ...        200        200        200
# 53      port 34    x  2020  port 34  ...          1          7          0
# 54      port 34    x  2020  port 34  ...        200        200        200
# 55       ticino    x  2019  port 34  ...         10         15         18
# 56      port 34    x  2020  port 34  ...          2          2          2
# 57      port 34    x  2020  port 34  ...          0          1          1
# 58         biel    x  2021     home  ...          0          0          0
# 59         biel    x  2021     home  ...          0         14         21
# 60         biel    9  2021     home  ...          6          7          8
# 61         biel    8  2021     home  ...          0          0          0
# 62      port 34    x  2015  port 34  ...          0          0          1
# 63  canton-bern    x  2019  port 34  ...        200        200        200
# 64      port 34    x  2015  port 34  ...          2          2          2
# 65      port 34    x  2016  port 34  ...        200        200        200
# 66      port 34    x  2019  port 34  ...          0          0          0
# 67      port 34    x  2015  port 34  ...        200        200        200
# 68  canton-bern    x  2020     home  ...          0          0          0
# 69      port 34    x  2015  port 34  ...         46         45         31
# 70      port 34    x  2016  port 34  ...          0          0          0
# 71      port 34    x  2015  port 34  ...          0          0          0
# 72         biel   10  2021     home  ...         29        200        200
# 73         biel   10  2021     home  ...          2          2          5
# 74         biel    8  2020     home  ...         15         19         22
# 75         biel   10  2021     home  ...          2          4          4
# 76      port 34    x  2015  port 34  ...          0          0          0
# 77      port 34    x  2015  port 34  ...          0          0          0
# 78      port 34  NaN  2015  port 34  ...          0          1          1
# 79         biel    x  2021     home  ...          9         15         15
# 80         biel    x  2021     home  ...          0          3          7
# 81      port 34    x  2015  port 34  ...          0          0          0
# 82         biel    7  2021     home  ...          3          3          3
# 83         biel    9  2021     home  ...          0          0          1
# 84         biel   10  2021     home  ...          0          4          5
# 85          cdf   10  2021     home  ...          0          1          2
# 86          cdf   10  2021     home  ...          0          1          2
# 87          cdf   10  2021     home  ...          0          1          1
# 88         biel   10  2021     home  ...          0          0          0
# 89          cdf   10  2021     home  ...        200        200        200
# 90          cdf   10  2021     home  ...          0          0          0
#
#    2021-11-03 2021-11-10 2021-11-18  2021-11-23  2021-11-28         genus  \
# 12         24         24         24          26          26       felseck
# 13         40         50         50          60          60       felseck
# 48          2          1          0           2           2  helianthemum
# 49        200        200        200          42          42        silene
# 50         19         18         10           5           5    matricaria
# 51        200        200        200          15          15         malva
# 52        200        200        200         200         200     hypericum
# 53          0          3         25          26          26     campanula
# 54        200        200        200         200         200     cichorium
# 55         28         27         27          27          27         aster
# 56          2          3          8          12          12      lathyrus
# 57          2          3          4           4           4      geranium
# 58          2          2          0           0           0       verbena
# 59         26        200        200          31          31      dipsacus
# 60          8          8          8           7           7     trifolium
# 61          0          0          0           0           0          geum
# 62          0          0          0           0           0     epilobium
# 63        200        200        200          32          32        isatis
# 64          2          2          2           3           3    matricaria
# 65        200        200        200         100         100     lavendula
# 66          0          0          0           0           0        salvia
# 67        200        200        200          75          75      anthemis
# 68          0          0          2           2           2         viola
# 69         15         15         15           8           8     verbascum
# 70          0          1          1           1           1    levisticum
# 71          6         13         16          23          23    polemonium
# 72        200        200        200          48          28      plantago
# 73          5          5          3           2           2     melilotus
# 74         25        200        200          42          42         malva
# 75          4          4          2           1           1        daucus
# 76          0          0          0           0           0      scabiosa
# 77          0          0          0           0           0     valeriana
# 78          1          1          1           1           1         aster
# 79         16         16         16          18          18      teucrium
# 80         14         22         28          27          27      teucrium
# 81          0          0          0           0           0     campanula
# 82          2          1          1           1           1       cirsium
# 83          0          2          2           2           2       special
# 84          6          6          5           5           5      plantago
# 85          2          2          1           1           1      achillea
# 86          2          0          0           0           0   filipendula
# 87          1          0          0           0           0     heracleum
# 88          2          2          3           4           4      prunella
# 89        200        200        200          35          35      achillea
# 90          1          1          0           0           0         malva
#
#                 int
# 12          felseck
# 13          felseck
# 48          port-34
# 49  rue-de-l'avenir
# 50       cygnes-lot
# 51       cygnes-lot
# 52          port-34
# 53          port-34
# 54  ursula-albrecht
# 55           ticino
# 56          port-34
# 57          port-34
# 58         port-lot
# 59         port-lot
# 60          felseck
# 61          pfeidli
# 62          port-34
# 63             bern
# 64          port-34
# 65          port-34
# 66          port-34
# 67          port-34
# 68    pres-la-patte
# 69          port-34
# 70          port-34
# 71          port-34
# 72       cygnes-lot
# 73       cygnes-lot
# 74     zentralplatz
# 75       cygnes-lot
# 76          port-34
# 77          port-34
# 78          port-34
# 79          felseck
# 80          felseck
# 81          port-34
# 82       cygnes-lot
# 83          felseck
# 84        alt-stadt
# 85          cdf-cff
# 86          cdf-cff
# 87          cdf-cff
# 88        alt-stadt
# 89          cdf-cff
# 90          cdf-cff
#
# [45 rows x 34 columns]

# %%
concs = conc[['2021-10-10', '2021-10-12', '2021-10-14',
       '2021-10-16', '2021-10-18', '2021-10-20', '2021-10-22', '2021-10-24',
       '2021-10-26', '2021-10-28', '2021-10-30', '2021-11-03', '2021-11-10',
       '2021-11-18', '2021-11-23', '2021-11-28']].copy()


concs.columns = pd.to_datetime(concs.columns)
conc2 = concs

# %%
cont["area"] = cont["area"].astype(int)

# %%
cont["test"] = cont["2021-10-12"]/cont["area"]

# %%
ger.columns = ger

# %%
conc["2021-10-30"].unique()
# Out:
# array(['22', '37', '2', 'full', '20', '0', '18', '1', '21', '8', '31',
#        '5', '4', '15', '7', '3'], dtype=object)

# %% [markdown]
# ## Germination

# %% [markdown]
# ### non-date columns information

# %%
# sloc = storage location column; indicates where the seeds were stored, grosso modo
# pmet = planting-method column; indicates how the seeds were planted. All followed about the same protocol so maybe not necessary, only rhinanthus differed.
# density = density of seeds used (small, medium, high)
# area = indicates how many germination cells or how what fraction of a container was dedicated to the plants
# colm = collection month
# coly = collection year
# collection column indicates whether the seed originated with volo or was collected by me
# container column indicates which container the seeds were planted in. plastic trays used cells, concrete containers were divided into 6 or into 2.
# origin column indicates where the seed came from
# geo column provides a useful grouping: Biel (cygnes-lot, port-lot, alt-stadt, biel-cff, a-5, felseck, zentralplatz), 
# port 34 (ursula-albrecht + port-34),
# canton-bern (lobsigen, pres-la-patte, jorat, cdf-forest, cdf-cff, pfeidli, bern, rubigen),
# ticino (ticino)

# %%
## start to play with berms and stuff (second part of location string e.g. Bermenstrasse-berm-1)

# %%
## project column, lots column, river column, forest column,
